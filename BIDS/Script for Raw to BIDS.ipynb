# %% [markdown]
# https://github.com/NILAB-UvA/bidsify

# %%
! pip install bidsify
# Out:
# ...
#   Created wheel for bidsify: filename=bidsify-0.3.7-py3-none-any.whl size=25355 sha256=e5b1cf92a501ed432a1f617f987b45d81ae8dc5bc1449c3d8c46e54c95e3f277
#   Stored in directory: /Users/sylvainiceta/Library/Caches/pip/wheels/f3/3d/5b/bad12a6cb525c82dabe017f0f2ce06f83faf5d3c4b3ea9d6f9
# Successfully built bidsify
# ...

# %% [markdown]
# Current version used : bidsify-0.3.7 (05/25/2020)

# %%
bidsify /Users/sylvainiceta/Documents/NouveauxScan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0cc64c44d10d> in <module>
# ----> 1 bidsify /Users/sylvainiceta/Documents/NouveauxScan
#
# NameError: name 'bidsify' is not defined
